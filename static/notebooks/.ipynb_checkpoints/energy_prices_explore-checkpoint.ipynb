# %%
## Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
## Source: http://www.ecdms.energy.ca.gov
filename = "MER_T09_08.csv"
filepath = os.path.join("..","data",filename)

prices = pd.read_csv(filepath,index_col=False)
prices.head()
# Out:
#        MSN  YYYYMM Value  Column_Order  \
# 0  ESRCUUS  196013   2.6             1
# 1  ESRCUUS  196113   2.6             1
# 2  ESRCUUS  196213   2.6             1
# 3  ESRCUUS  196313   2.5             1
# 4  ESRCUUS  196413   2.5             1
#
#                                         Description  \
# 0  Average Retail Price of Electricity, Residential
# 1  Average Retail Price of Electricity, Residential
# 2  Average Retail Price of Electricity, Residential
# 3  Average Retail Price of Electricity, Residential
# 4  Average Retail Price of Electricity, Residential
#
#                                        Unit
# 0  Cents per Kilowatthour,  Including Taxes
# 1  Cents per Kilowatthour,  Including Taxes
# 2  Cents per Kilowatthour,  Including Taxes
# 3  Cents per Kilowatthour,  Including Taxes
# 4  Cents per Kilowatthour,  Including Taxes

# %%
prices.columns
# Out:
# Index(['MSN', 'YYYYMM', 'Value', 'Column_Order', 'Description', 'Unit'], dtype='object')

# %%
prices['Description'].value_counts()
# Out:
# Average Retail Price of Electricity, Commercial        565
# Average Retail Price of Electricity, Residential       565
# Average Retail Price of Electricity, Transportation    565
# Average Retail Price of Electricity, Total             565
# Average Retail Price of Electricity, Other             565
# Average Retail Price of Electricity, Industrial        565
# Name: Description, dtype: int64

# %%
prices['Column_Order'].value_counts()
# Out:
# 5    565
# 3    565
# 1    565
# 6    565
# 4    565
# 2    565
# Name: Column_Order, dtype: int64

# %%
residential = prices.loc[prices['Description']== "Average Retail Price of Electricity, Residential"]
# Out:
#          MSN  YYYYMM          Value  Column_Order  \
# 0    ESRCUUS  196013            2.6             1
# 1    ESRCUUS  196113            2.6             1
# 2    ESRCUUS  196213            2.6             1
# 3    ESRCUUS  196313            2.5             1
# 4    ESRCUUS  196413            2.5             1
# 5    ESRCUUS  196513            2.4             1
# 6    ESRCUUS  196613            2.3             1
# 7    ESRCUUS  196713            2.3             1
# 8    ESRCUUS  196813            2.3             1
# 9    ESRCUUS  196913            2.2             1
# 10   ESRCUUS  197013            2.2             1
# 11   ESRCUUS  197113            2.3             1
# 12   ESRCUUS  197213            2.4             1
# 13   ESRCUUS  197313            2.5             1
# 14   ESRCUUS  197413            3.1             1
# 15   ESRCUUS  197513            3.5             1
# 16   ESRCUUS  197601  Not Available             1
# 17   ESRCUUS  197602  Not Available             1
# 18   ESRCUUS  197603  Not Available             1
# 19   ESRCUUS  197604  Not Available             1
# 20   ESRCUUS  197605  Not Available             1
# 21   ESRCUUS  197606  Not Available             1
# 22   ESRCUUS  197607            3.9             1
# 23   ESRCUUS  197608            3.7             1
# 24   ESRCUUS  197609            3.8             1
# ..                                                ...
# 535  Average Retail Price of Electricity, Residential
# 536  Average Retail Price of Electricity, Residential
# 537  Average Retail Price of Electricity, Residential
# 538  Average Retail Price of Electricity, Residential
# 539  Average Retail Price of Electricity, Residential
# 540  Average Retail Price of Electricity, Residential
# 541  Average Retail Price of Electricity, Residential
# 542  Average Retail Price of Electricity, Residential
# 543  Average Retail Price of Electricity, Residential
# 544  Average Retail Price of Electricity, Residential
# 545  Average Retail Price of Electricity, Residential
# 546  Average Retail Price of Electricity, Residential
# 547  Average Retail Price of Electricity, Residential
# 548  Average Retail Price of Electricity, Residential
# 549  Average Retail Price of Electricity, Residential
# 550  Average Retail Price of Electricity, Residential
# 551  Average Retail Price of Electricity, Residential
# 552  Average Retail Price of Electricity, Residential
# 553  Average Retail Price of Electricity, Residential
# 554  Average Retail Price of Electricity, Residential
# 555  Average Retail Price of Electricity, Residential
# 556  Average Retail Price of Electricity, Residential
# 557  Average Retail Price of Electricity, Residential
# 558  Average Retail Price of Electricity, Residential
# 559  Average Retail Price of Electricity, Residential
# 560  Average Retail Price of Electricity, Residential
# 561  Average Retail Price of Electricity, Residential
# 562  Average Retail Price of Electricity, Residential
# 563  Average Retail Price of Electricity, Residential
# 564  Average Retail Price of Electricity, Residential
#
#                                          Unit
# 0    Cents per Kilowatthour,  Including Taxes
# 1    Cents per Kilowatthour,  Including Taxes
# 2    Cents per Kilowatthour,  Including Taxes
# 3    Cents per Kilowatthour,  Including Taxes
# 4    Cents per Kilowatthour,  Including Taxes
# 5    Cents per Kilowatthour,  Including Taxes
# 6    Cents per Kilowatthour,  Including Taxes
# 7    Cents per Kilowatthour,  Including Taxes
# 8    Cents per Kilowatthour,  Including Taxes
# 9    Cents per Kilowatthour,  Including Taxes
# 10   Cents per Kilowatthour,  Including Taxes
# 11   Cents per Kilowatthour,  Including Taxes
# 12   Cents per Kilowatthour,  Including Taxes
# 13   Cents per Kilowatthour,  Including Taxes
# 14   Cents per Kilowatthour,  Including Taxes
# 15   Cents per Kilowatthour,  Including Taxes
# 16   Cents per Kilowatthour,  Including Taxes
# 17   Cents per Kilowatthour,  Including Taxes
# 18   Cents per Kilowatthour,  Including Taxes
# 19   Cents per Kilowatthour,  Including Taxes
# 20   Cents per Kilowatthour,  Including Taxes
# 21   Cents per Kilowatthour,  Including Taxes
# 22   Cents per Kilowatthour,  Including Taxes
# 23   Cents per Kilowatthour,  Including Taxes
# 24   Cents per Kilowatthour,  Including Taxes
# 25   Cents per Kilowatthour,  Including Taxes
# 26   Cents per Kilowatthour,  Including Taxes
# 27   Cents per Kilowatthour,  Including Taxes
# 28   Cents per Kilowatthour,  Including Taxes
# 29   Cents per Kilowatthour,  Including Taxes
# ..                                        ...
# 535  Cents per Kilowatthour,  Including Taxes
# 536  Cents per Kilowatthour,  Including Taxes
# 537  Cents per Kilowatthour,  Including Taxes
# 538  Cents per Kilowatthour,  Including Taxes
# 539  Cents per Kilowatthour,  Including Taxes
# 540  Cents per Kilowatthour,  Including Taxes
# 541  Cents per Kilowatthour,  Including Taxes
# 542  Cents per Kilowatthour,  Including Taxes
# 543  Cents per Kilowatthour,  Including Taxes
# 544  Cents per Kilowatthour,  Including Taxes
# 545  Cents per Kilowatthour,  Including Taxes
# 546  Cents per Kilowatthour,  Including Taxes
# 547  Cents per Kilowatthour,  Including Taxes
# 548  Cents per Kilowatthour,  Including Taxes
# 549  Cents per Kilowatthour,  Including Taxes
# 550  Cents per Kilowatthour,  Including Taxes
# 551  Cents per Kilowatthour,  Including Taxes
# 552  Cents per Kilowatthour,  Including Taxes
# 553  Cents per Kilowatthour,  Including Taxes
# 554  Cents per Kilowatthour,  Including Taxes
# 555  Cents per Kilowatthour,  Including Taxes
# 556  Cents per Kilowatthour,  Including Taxes
# 557  Cents per Kilowatthour,  Including Taxes
# 558  Cents per Kilowatthour,  Including Taxes
# 559  Cents per Kilowatthour,  Including Taxes
# 560  Cents per Kilowatthour,  Including Taxes
# 561  Cents per Kilowatthour,  Including Taxes
# 562  Cents per Kilowatthour,  Including Taxes
# 563  Cents per Kilowatthour,  Including Taxes
# 564  Cents per Kilowatthour,  Including Taxes
#
# [565 rows x 6 columns]

# %%
ByDesc = prices.groupby('Description')

# %%
ByDesc['Value'].describe()
# Out:
#                                                    count unique  \
# Description
# Average Retail Price of Electricity, Commercial      565    272
# Average Retail Price of Electricity, Industrial      565    232
# Average Retail Price of Electricity, Other           565    108
# Average Retail Price of Electricity, Residential     565    307
# Average Retail Price of Electricity, Total           565    267
# Average Retail Price of Electricity, Transporta...   565    146
#
#                                                                top freq
# Description
# Average Retail Price of Electricity, Commercial      Not Available   78
# Average Retail Price of Electricity, Industrial      Not Available   78
# Average Retail Price of Electricity, Other          Not Applicable  198
# Average Retail Price of Electricity, Residential     Not Available   78
# Average Retail Price of Electricity, Total           Not Available   78
# Average Retail Price of Electricity, Transporta...   Not Available  367

# %%
residential.columns
# Out:
# Index(['MSN', 'YYYYMM', 'Value', 'Column_Order', 'Description', 'Unit'], dtype='object')

# %%
residential.drop(columns=['MSN','Column_Order','Description','Unit'])

# %%
r = residential.drop(columns=['MSN','Column_Order','Description','Unit'])

# %%
r = r.loc[r['Value'] != "Not Available"]
r["dates"] = r['YYYYMM'].astype(str)
#remove rows tha contain 13 in the string
r = r.loc[~r['dates'].str.contains('13')]

# %%
r.drop(columns=["dates"]).to_csv("../data/monthprices.csv", index=False)

# %%
tosave= r.drop(columns=["dates"])
