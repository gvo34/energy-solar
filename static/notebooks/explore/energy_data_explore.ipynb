# %%
## Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import os

output_data = "../../data/output"
input_data = "../../data/input"

# %% [markdown]
# # Source EIA

# %%
## Source: https://www.eia.gov/totalenergy/data/browser/?tbl=T10.05#/?f=M
filename = "MER_T10_05.csv"
filepath = os.path.join(input_data,filename)

eiadf = pd.read_csv(filepath)
print(len(eiadf))
eiadf.head()
# Out:
# 6732
#        MSN  YYYYMM          Value  Column_Order  \
# 0  SOT8BUS  194913  Not Available             1
# 1  SOT8BUS  195013  Not Available             1
# 2  SOT8BUS  195113  Not Available             1
# 3  SOT8BUS  195213  Not Available             1
# 4  SOT8BUS  195313  Not Available             1
#
#                                          Description          Unit
# 0  Distributed Solar Energy Consumption for Heat:...  Trillion Btu
# 1  Distributed Solar Energy Consumption for Heat:...  Trillion Btu
# 2  Distributed Solar Energy Consumption for Heat:...  Trillion Btu
# 3  Distributed Solar Energy Consumption for Heat:...  Trillion Btu
# 4  Distributed Solar Energy Consumption for Heat:...  Trillion Btu

# %%
## Source: https://www.eia.gov/totalenergy/data/browser/?tbl=T10.01#/?f=M
filename = "MER_T10_01.csv"
filepath = os.path.join(input_data,filename)

eiadf1 = pd.read_csv(filepath)
eiadf1.head()
# Out:
#        MSN  YYYYMM          Value  Column_Order          Description  \
# 0  BFPRBUS  194913  Not Available             1  Biofuels Production
# 1  BFPRBUS  195013  Not Available             1  Biofuels Production
# 2  BFPRBUS  195113  Not Available             1  Biofuels Production
# 3  BFPRBUS  195213  Not Available             1  Biofuels Production
# 4  BFPRBUS  195313  Not Available             1  Biofuels Production
#
#            Unit
# 0  Trillion Btu
# 1  Trillion Btu
# 2  Trillion Btu
# 3  Trillion Btu
# 4  Trillion Btu

# %%
## Source: https://www.eia.gov/totalenergy/data/browser/?tbl=T02.02#/?f=M
filename = "MER_T02_02.csv"
filepath = os.path.join(input_data,filename)

eiadf2 = pd.read_csv(filepath)
print(len(eiadf2))
eiadf2.head()
# Out:
# 7344
#        MSN  YYYYMM     Value  Column_Order  \
# 0  CLRCBUS  194913  1271.551             1
# 1  CLRCBUS  195013  1261.267             1
# 2  CLRCBUS  195113  1158.679             1
# 3  CLRCBUS  195213  1079.206             1
# 4  CLRCBUS  195313   965.664             1
#
#                                Description          Unit
# 0  Coal Consumed by the Residential Sector  Trillion Btu
# 1  Coal Consumed by the Residential Sector  Trillion Btu
# 2  Coal Consumed by the Residential Sector  Trillion Btu
# 3  Coal Consumed by the Residential Sector  Trillion Btu
# 4  Coal Consumed by the Residential Sector  Trillion Btu

# %%
eiadf['Unit'].value_counts()
# Out:
# Trillion Btu    6732
# Name: Unit, dtype: int64

# %%
eiadf1['Unit'].value_counts()
# Out:
# Trillion Btu    7344
# Name: Unit, dtype: int64

# %%
eiadf2['Unit'].value_counts()
# Out:
# Trillion Btu    7344
# Name: Unit, dtype: int64

# %%
eiadf['Description'].value_counts()
# Out:
# Distributed Solar Energy Consumption for Electricity:  Total                       612
# Solar Energy Consumption                                                           612
# Distributed Solar Energy Consumption for Electricity:  Industrial Sector           612
# Utility-Scale Solar Energy Consumption: Total                                      612
# Distributed Solar Energy Consumption:  Total                                       612
# Distributed Solar Energy Consumption for Electricity:  Residential Sector          612
# Utility-Scale Solar Energy Consumption for Electricity: Commercial Sector          612
# Utility-Scale Solar Energy Consumption for Electricity: Industrial Sector          612
# Distributed Solar Energy Consumption for Electricity:  Commercial Sector           612
# Utility-Scale Solar Energy Consumption for Electricity:  Electric Power Sector     612
# Distributed Solar Energy Consumption for Heat:  Total                              612
# Name: Description, dtype: int64

# %%
eiadf1['Description'].value_counts()
# Out:
# Waste Energy Consumption              612
# Wood Energy Consumption               612
# Solar Energy Consumption              612
# Geothermal Energy Consumption         612
# Total Biomass Energy Production       612
# Total Biomass Energy Consumption      612
# Total Renewable Energy Production     612
# Total Renewable Energy Consumption    612
# Hydroelectric Power Consumption       612
# Biofuels Consumption                  612
# Wind Energy Consumption               612
# Biofuels Production                   612
# Name: Description, dtype: int64

# %%
eiadf2['Description'].value_counts()
# Out:
# Electricity Retail Sales to the Residential Sector                                       612
# Natural Gas Consumed by the Residential Sector (Excluding Supplemental Gaseous Fuels)    612
# Petroleum Consumed by the Residential Sector                                             612
# Total Fossil Fuels Consumed by the Residential Sector                                    612
# Residential Sector Electrical System Energy Losses                                       612
# Total Renewable Energy Consumed by the Residential Sector                                612
# Geothermal Energy Consumed by the Residential Sector                                     612
# Total Energy Consumed by the Residential Sector                                          612
# Coal Consumed by the Residential Sector                                                  612
# Solar Energy Consumed by the Residential Sector                                          612
# Total Primary Energy Consumed by the Residential Sector                                  612
# Biomass Energy Consumed by the Residential Sector                                        612
# Name: Description, dtype: int64

# %% [markdown]
# #### Not all rows correspond to the same category. We need to select just one, this reduces the data from 612 records to 445

# %%
# v = eiadf.loc[eiadf['Description']=="Solar Energy Consumption"]
# v = v.loc[v['Value'] != "Not Available"]
# len(v)
v = eiadf.loc[(eiadf['Description'] == "Solar Energy Consumption") & 
              (eiadf['Value'] != "Not Available")]
v.dtypes
# Out:
# MSN             object
# YYYYMM           int64
# Value           object
# Column_Order     int64
# Description     object
# Unit            object
# dtype: object

# %%
v.head()
v1 = v[["YYYYMM","Value"]]

# %% [markdown]
# #### Further clean up to remove totals YYYY13 records reduces the data to 399 rows

# %%
#remove the data for month 13 (total year consumption)
# make a copy to a string type
v["dates"] = v['YYYYMM'].astype(str)
#v["dates"] = pd.to_datetime(v["YYYYMM"], format="%Y%m")
#remove rows tha contain 13 in the string
v = v.loc[~v['dates'].str.contains(r'13$')]
# Out:
# /anaconda3/envs/PythonData_3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#v = v.drop(columns=['MSN','Column_Order',"Description","Unit","dates"])
#v.to_csv("../data/monthdata.csv", index=False)
len(v)
# Out:
# 411

# %%
v.plot()

# %%
plt.show()

# %%
#remove values totals respresented with YYYY13

# %%
eiadf1['Description'].value_counts()
# Out:
# Waste Energy Consumption              612
# Wood Energy Consumption               612
# Solar Energy Consumption              612
# Geothermal Energy Consumption         612
# Total Biomass Energy Production       612
# Total Biomass Energy Consumption      612
# Total Renewable Energy Production     612
# Total Renewable Energy Consumption    612
# Hydroelectric Power Consumption       612
# Biofuels Consumption                  612
# Wind Energy Consumption               612
# Biofuels Production                   612
# Name: Description, dtype: int64

# %%
print(len(eiadf1))
values1 = eiadf1[['Value', 'YYYYMM', 'Description']]
#values.filter(lambda x: x['YYYYMM'].astype(str)[-2])



from datetime import datetime
df=[]
for i, row in values.iterrows():
    if(str(row["YYYYMM"])[-2:]=='13' or row["Value"]=="No Data Reported"):
        continue
    else:
        df.append(row)
ls1 = [float(i["Value"]) for i in df]
ls2 = [datetime.strptime(str(i["YYYYMM"]),"%Y%m") for i in df]
df = pd.DataFrame(data={"YYYYMM":ls2,"Value":ls1, })
df


#[i for i in list(values.loc[:,"YYYYMM"]) if str(i)[-2] =="13"]
# Out:
#          YYYYMM   Value
# 0    1989-01-01   2.792
# 1    1989-02-01   3.010
# 2    1989-03-01   4.147
# 3    1989-04-01   4.571
# 4    1989-05-01   5.046
# 5    1989-06-01   5.092
# 6    1989-07-01   5.345
# 7    1989-08-01   5.290
# 8    1989-09-01   4.825
# 9    1989-10-01   4.397
# 10   1989-11-01   3.607
# 11   1989-12-01   3.424
# 12   1990-01-01   2.958
# 13   1990-02-01   3.189
# 14   1990-03-01   4.393
# 15   1990-04-01   4.842
# 16   1990-05-01   5.345
# 17   1990-06-01   5.394
# 18   1990-07-01   5.662
# 19   1990-08-01   5.603
# 20   1990-09-01   5.111
# 21   1990-10-01   4.658
# 22   1990-11-01   3.821
# 23   1990-12-01   3.627
# 24   1991-01-01   3.051
# 25   1991-02-01   3.288
# 26   1991-03-01   4.531
# 27   1991-04-01   4.994
# 28   1991-05-01   5.513
# 29   1991-06-01   5.562
# ...         ...     ...
# 3531 2015-10-01  34.208
# 3532 2015-11-01  29.576
# 3533 2015-12-01  27.154
# 3534 2016-01-01  25.996
# 3535 2016-02-01  35.041
# 3536 2016-03-01  43.282
# 3537 2016-04-01  47.932
# 3538 2016-05-01  55.174
# 3539 2016-06-01  56.232
# 3540 2016-07-01  61.492
# 3541 2016-08-01  60.982
# 3542 2016-09-01  55.312
# 3543 2016-10-01  48.917
# 3544 2016-11-01  41.301
# 3545 2016-12-01  37.004
# 3546 2017-01-01  34.568
# 3547 2017-02-01  39.401
# 3548 2017-03-01  64.409
# 3549 2017-04-01  70.208
# 3550 2017-05-01  82.084
# 3551 2017-06-01  87.309
# 3552 2017-07-01  81.295
# 3553 2017-08-01  79.435
# 3554 2017-09-01  74.195
# 3555 2017-10-01  68.260
# 3556 2017-11-01  47.416
# 3557 2017-12-01  45.697
# 3558 2018-01-01  48.632
# 3559 2018-02-01  57.253
# 3560 2018-03-01  74.537
#
# [3561 rows x 2 columns]

# %% [markdown]
# ## Source ECDMS - Not Used

# %%
## Source: http://www.ecdms.energy.ca.gov
filename = "ElectricityByUtility.csv"
filepath = os.path.join(input_data,filename)

ecdmsdf = pd.read_csv(filepath)

# %% [markdown]
# Number of total rows available

# %%
print(len(ecdmsdf))
ecdmsdf.columns
# Out:
# 1561
# Index(['Utility Type', 'Utility Name', 'Year', 'Ag & Water Pump',
#        'Commercial Building', 'Commercial Other', 'Industry',
#        'Mining & Construction', 'Residential', 'Streetlight', 'Total Usage'],
#       dtype='object')

# %% [markdown]
# Number of rows per year

# %%
yearly_data = ecdmsdf['Year'].value_counts()

# %% [markdown]
# #### Not a rich enough time series.. moving on to the next data source

# %% [markdown]
# only 60+ records to use, change source
